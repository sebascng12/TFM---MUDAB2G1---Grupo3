# %% [markdown]
# # MUDAB2G1 - Grupo 3 - TFM: Modelo de predicción de precios de acciones

# %% [markdown]
# Este notebook pertenece al Grupo 3 del MUDAB2G1. Cuyos miembros de equipo son:
#
# *   Carrillo Ng, Sebastián Elías
# *   Cifuentes Guzmán, Yaros Josué
# *   Donoso Muñoz, Javier Esteban

# %% [markdown]
# ## Objetivo del Notebook: construcción de datasets
#
# El objetivo de este notebook es preparar dos datasets relevantes para la creación de nuestro modelo de predicción de precios de las acciones del mercado bursátil. Para ello utilizaremos dos pipelines (i) extracción de precios de acciones y (ii) extracción de noticias. En cada una de las secciones se detalla con mayor profundidad la metodología y razonamiento planteado.

# %% [markdown]
# ## Pipeline de Extracción de Precios de Acciones
#
# Esta sección tiene como objetivo recopilar los precios históricos de las acciones correspondientes a las empresas que serán objeto de estudio en esta investigación. Para ello, se emplea la librería yfinance, la cual permite acceder de forma programática a datos financieros provenientes de Yahoo Finance.
#
# Se procederá a enriquecer el conjunto de datos con una serie de variables derivadas que permiten caracterizar aspectos esenciales del comportamiento del activo.
#
# En resumen, el pipeline propuesto sigue el siguiente orden:
#
# Recolección de precios de acciones → Enriquecimiento de features → Exportación a CSV

# %% [markdown]
# ### Preparación del entorno

# %% [markdown]
# Se importan todas las librerías necesarias para la obtención de datos

# %%
import yfinance as yf
import datetime
from datetime import datetime, date
import pandas as pd

# %% [markdown]
# ### Obtención de precios

# %% [markdown]
# Se utiliza el parámetro del nombre de la empresa en la Bolsa de Valores americana para poder obtener un dataset financiero

# %%
# Parámetros
stock = 'TSLA'
start = datetime.datetime(2018, 12, 1)
end = datetime.datetime(2025, 1, 31)

# Descargar datos
data = yf.download(stock, start=start, end=end, actions=True)
data = data.reset_index()
data.head(1)

# %%
# Aplanar columnas si tienen MultiIndex
if isinstance(data.columns, pd.MultiIndex):
    data.columns = ['_'.join(col).strip() if isinstance(col, tuple) else col for col in data.columns]

# Verificar nombres actuales
print("Columnas originales:", data.columns.tolist())

# Forzar nombres limpios (orden esperado de columnas)
df = data.copy()
df.columns = ['date', 'close', 'dividends', 'high', 'low', 'open', 'stock_splits', 'volume']

# Reordenar columnas en el orden deseado
desired_order = ['date', 'open', 'high', 'low', 'close', 'volume', 'dividends', 'stock_splits']
df = df[desired_order]

# Resultado final
print("✅ DataFrame limpio:")
df.head()

# %% [markdown]
# ### Ingeniería de features

# %% [markdown]
# Se crean una serie de variables adicionales a partir del precio histórico que capturan diferentes dimensiones del comportamiento bursátil. Entre ellas se incluyen medidas de tendencia como la media móvil exponencial (EMA), valores pasados del precio que introducen memoria temporal, retornos porcentuales diarios y semanales que reflejan la rentabilidad reciente, y métricas de volatilidad como la desviación estándar móvil y el rango de precios intradiarios. Estas variables permiten al modelo incorporar señales cuantitativas clave del mercado en sus predicciones.

# %%
# Calcular media móvil exponencial
df['ema'] = df['close'].ewm(span=15, adjust=False).mean()

# Crear variables derivadas
df['close_lag1'] = df['close'].shift(1)
df['close_lag2'] = df['close'].shift(2)
df['return_1d'] = df['close'].pct_change(1)
df['return_7d'] = df['close'].pct_change(7)
df['volatility_7d'] = df['close'].rolling(window=7).std()
df['price_range'] = df['high'] - df['low']
df['price_range_7d'] = df['price_range'].rolling(window=7).mean()

# Limpiar valores nulos
df = df.sort_values('date').reset_index(drop=True)
# Guardar resultado
df.to_csv(f"{stock}_stock_features.csv", index=False)
df.head()

# %% [markdown]
# ## Pipeline de Extracción de Noticias
#
# Esta sección del notebook tiene como objetivo recopilar noticias financieras relevantes, extraer su contenido y analizar su sentimiento para integrarlos como variables explicativas en un modelo de predicción del precio de acciones.
#
# A través de diferentes secciones, se emplean herramientas como GNews, técnicas de web scraping, y modelos de análisis de sentimiento como TextBlob, Vader y FinBERT. El pipeline está diseñado para automatizar el proceso desde la recolección de noticias hasta la generación de variables numéricas que representen el tono de los artículos.
#
# En resumen, el pipeline propuesto sigue el siguiente orden:
#
# Recolección de noticias → Limpieza de URLs → Extracción de texto → Análisis de sentimiento → Exportación a CSV

# %% [markdown]
# ### Preparar el entorno

# %% [markdown]
# Se importan todas las librerías que se utilizaran en esta sección del proyecto

# %%
# !pip install swifter
# !pip install scipy
# !pip install tqdm
# !pip install requests
# !pip install beautifulsoup4
# !pip install newspaper3k
# !pip install selenium
# !pip install nltk
# !pip install gnews
# !pip install googlenewsdecoder
# !pip install textblob
# !pip install transformers
# !pip install vaderSentiment
# !pip install torch

import os
import re
import time
import urllib.parse
from datetime import datetime, timedelta

os.environ["TRANSFORMERS_NO_TF"] = "1"

# Manejo de datos
import numpy as np
import pandas as pd
from scipy.special import softmax
from tqdm import tqdm
from tqdm.notebook import tqdm as notebook_tqdm
import swifter

# Scrappeo y parseo
import requests
from bs4 import BeautifulSoup
from newspaper import Article
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Herramientas NLP
import nltk
from gnews import GNews
from googlenewsdecoder import new_decoderv1
from textblob import TextBlob, download_corpora
from transformers import AutoModelForSequenceClassification, AutoTokenizer, AutoModel
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import torch
nltk.download('punkt')
# Out:
# Requirement already satisfied: swifter in /usr/local/lib/python3.11/dist-packages (1.4.0)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from swifter) (2.2.2)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.11/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2024.12.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.11/dist-packages (from swifter) (4.67.1)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (2025.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.11/dist-packages (from dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (8.7.0)
# Requirement already satisfied: dask-expr<1.2,>=1.1 in /usr/local/lib/python3.11/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.1.21)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.0.0->swifter) (2025.2)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.11/dist-packages (from dask-expr<1.2,>=1.1->dask[dataframe]>=2.10.0->swifter) (18.1.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata>=4.13.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (3.23.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.11/dist-packages (from partd>=1.4.0->dask>=2.10.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->swifter) (1.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.6.15)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.13.2)
# Requirement already satisfied: newspaper3k in /usr/local/lib/python3.11/dist-packages (0.2.8)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (4.13.4)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (11.2.1)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (6.0.2)
# Requirement already satisfied: cssselect>=0.9.2 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (1.3.0)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (5.4.0)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (3.9.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (2.32.3)
# Requirement already satisfied: feedparser>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (6.0.11)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (5.3.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (2.9.0.post0)
# Requirement already satisfied: tinysegmenter==0.3 in /usr/local/lib/python3.11/dist-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (4.13.2)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.17.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.11/dist-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.1->newspaper3k) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.1->newspaper3k) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.1->newspaper3k) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.2.1->newspaper3k) (4.67.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.10.0->newspaper3k) (2025.6.15)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.11/dist-packages (from tldextract>=2.0.1->newspaper3k) (2.1.0)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.11/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.18.0)
# Requirement already satisfied: selenium in /usr/local/lib/python3.11/dist-packages (4.33.0)
# Requirement already satisfied: urllib3~=2.4.0 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.6.15)
# Requirement already satisfied: typing_extensions~=4.13.2 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8.0 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (3.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.30.0->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]~=2.4.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)
# Requirement already satisfied: gnews in /usr/local/lib/python3.11/dist-packages (0.4.1)
# Requirement already satisfied: feedparser~=6.0.2 in /usr/local/lib/python3.11/dist-packages (from gnews) (6.0.11)
# Requirement already satisfied: beautifulsoup4<5,>=4.9.3 in /usr/local/lib/python3.11/dist-packages (from gnews) (4.13.4)
# Requirement already satisfied: dnspython in /usr/local/lib/python3.11/dist-packages (from gnews) (2.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from gnews) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5,>=4.9.3->gnews) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4<5,>=4.9.3->gnews) (4.13.2)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.11/dist-packages (from feedparser~=6.0.2->gnews) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->gnews) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->gnews) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->gnews) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->gnews) (2025.6.15)
# Requirement already satisfied: googlenewsdecoder in /usr/local/lib/python3.11/dist-packages (0.1.7)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from googlenewsdecoder) (2.32.3)
# Requirement already satisfied: selectolax>=0.3.27 in /usr/local/lib/python3.11/dist-packages (from googlenewsdecoder) (0.3.30)
# Requirement already satisfied: pysocks>=1.7.1 in /usr/local/lib/python3.11/dist-packages (from googlenewsdecoder) (1.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->googlenewsdecoder) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->googlenewsdecoder) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->googlenewsdecoder) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->googlenewsdecoder) (2025.6.15)
# Requirement already satisfied: Cython==3.0.11 in /usr/local/lib/python3.11/dist-packages (from selectolax>=0.3.27->googlenewsdecoder) (3.0.11)
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.11/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.6.15)
# Collecting vaderSentiment
#   Using cached vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (2025.6.15)
# Using cached vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.3 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-1-3309026596.py in <cell line: 0>()
#      33 import requests
#      34 from bs4 import BeautifulSoup
# ---> 35 from newspaper import Article
#      36 from selenium import webdriver
#      37 from selenium.webdriver.chrome.options import Options
#
# /usr/local/lib/python3.11/dist-packages/newspaper/__init__.py in <module>
#       8 __copyright__ = 'Copyright 2014, Lucas Ou-Yang'
#       9
# ---> 10 from .api import (build, build_article, fulltext, hot, languages,
#      11                   popular_urls, Configuration as Config)
#      12 from .article import Article, ArticleException
#
# /usr/local/lib/python3.11/dist-packages/newspaper/api.py in <module>
#      12 import feedparser
#      13
# ---> 14 from .article import Article
#      15 from .configuration import Configuration
#      16 from .settings import POPULAR_URLS, TRENDING_URL
#
# /usr/local/lib/python3.11/dist-packages/newspaper/article.py in <module>
#      13
#      14 from . import images
# ---> 15 from . import network
#      16 from . import nlp
#      17 from . import settings
#
# /usr/local/lib/python3.11/dist-packages/newspaper/network.py in <module>
#      12 import requests
#      13
# ---> 14 from .configuration import Configuration
#      15 from .mthreading import ThreadPool
#      16 from .settings import cj
#
# /usr/local/lib/python3.11/dist-packages/newspaper/configuration.py in <module>
#      13 import logging
#      14
# ---> 15 from .parsers import Parser
#      16 from .text import (StopWords, StopWordsArabic, StopWordsChinese,
#      17                    StopWordsKorean, StopWordsHindi, StopWordsJapanese)
#
# /usr/local/lib/python3.11/dist-packages/newspaper/parsers.py in <module>
#      10 import lxml.etree
#      11 import lxml.html
# ---> 12 import lxml.html.clean
#      13 import re
#      14 from html import unescape
#
# /usr/local/lib/python3.11/dist-packages/lxml/html/clean.py in <module>
#      16     ]
#      17 except ImportError:
# ---> 18     raise ImportError(
#      19         "lxml.html.clean module is now a separate project lxml_html_clean.\n"
#      20         "Install lxml[html_clean] or lxml_html_clean directly."
#
# ImportError: lxml.html.clean module is now a separate project lxml_html_clean.
# Install lxml[html_clean] or lxml_html_clean directly.
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### Obtención de noticias (GNews)

# %% [markdown]
# En esta sección se encuentra el código para recorrer la web de GNews y conseguir las noticias por año de alguna empresa en particular (en este caso, para Tesla). A diferencia de las APIs de pago, este código realiza una búsqueda de acuerdo a la densidad de lo encontrado en internet sobre ese término. Parte de la premisa es que este código limita las búsquedas a un máximo de 100 documentos por consulta. Para evitar bloqueos y asegurar la obtención de los datos, introduce pausas entre cada día e itera sobre ellos de forma controlada.

# %%
def fx_timestamp():
    from datetime import datetime
    """
    Va a devolver un sello temporal para tenerlo en caso sea necesario
    """
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S.%f')[:-5]
    return timestamp

# %%
def split_date_range_and_process(keyword, start_date, end_date, sparseness):
    """
    Divide un rango de fechas en intervalos más pequeños según el nivel de dispersión y ejecuta una función en cada intervalo.

    Parámetros:
        start_date (str): Fecha de inicio en formato 'YYYY-MM-DD'.
        end_date (str): Fecha de fin en formato 'YYYY-MM-DD'.
        sparseness (str): Nivel de dispersión ('very sparse', 'sparse', 'medium', 'dense').
        function (callable): Función a ejecutar en cada intervalo. Debe aceptar start_date y end_date como argumentos.

    Retorna:
        pd.DataFrame: Resultados combinados de la función ejecutada en todos los intervalos.
    """
    # Convertir las fechas
    start_date_obj = datetime.strptime(start_date, "%Y-%m-%d")
    end_date_obj = datetime.strptime(end_date, "%Y-%m-%d")

    # Inicializar las variables
    current_start_date = start_date_obj
    combined_df = pd.DataFrame()

    # Hacer un loop por las fechas
    while current_start_date < end_date_obj:

        # Determinar el sparseness en base a lo que creemos que vamos a encontrar la data.

        if sparseness == 1:                           # "very sparse" = yearly
            increment = timedelta(days=365)
        elif sparseness == 2:                         # "sparse" = monthly
            increment = timedelta(days=30)
        elif sparseness == 3:                         # "medium" = weekly
            increment = timedelta(days=7)
        else:  # 4                                   # "dense" = daily
            increment = timedelta(days=1)


        current_end_date = current_start_date + increment
        if current_end_date > end_date_obj:
            current_end_date = end_date_obj

        start_date = current_start_date.strftime("%Y-%m-%d")
        end_date = current_end_date.strftime("%Y-%m-%d")

        # Función para sacar las noticias
        df, num_records = fetch_press_googlenewsrss_daterange(keyword, start_date, end_date, language = 'en')

        # Unir los resultados al dataframe combinado
        if not df.empty:
            combined_df = pd.concat([combined_df, df], ignore_index=True)

        # Moverse al siguiente intervalo
        current_start_date = current_end_date

        print("Sparseness at " + str(current_start_date) + ": "+ str(sparseness) + ". Records = " + str(num_records))

        if num_records >= 100:
            sparseness = sparseness + 1

        if sparseness == 5:
            print("Max records per search for "+ keyword + " reached at " + str(current_end_date) + " (daily). Recommend using a more specific keyword going forward.")

    return combined_df

def fetch_press_googlenewsrss_daterange(keyword, start_date, end_date, language = 'en'):

    all_dataframes = []

    start_date_obj = datetime.strptime(start_date, "%Y-%m-%d")
    end_date_obj = datetime.strptime(end_date, "%Y-%m-%d")

    start_date_str = str(start_date_obj)
    end_date_str = str(end_date_obj)

    print(start_date_str, end_date_str)

    # Traer todas las noticias de esa fecha
    # Ponerle 5 segundos para que no sea tan rápido y no se nos bloquee el scrappeo
    time.sleep(5)

    google_news = GNews(
    language=language,
    max_results=100 # 100 es el resultado máximo que puede salir en la búsqueda
    )

    google_news.start_date = (start_date_obj.year, start_date_obj.month, start_date_obj.day)
    google_news.end_date = (end_date_obj.year, end_date_obj.month, end_date_obj.day)

    news_json = google_news.get_news(keyword)

    df = pd.json_normalize(
        news_json,
        sep='_',
        errors='ignore'
    )

    if not df.empty:
        # Renombrar las columnas para un mejor entendimiento
        df = df.rename(columns={
            'title': 'ent_name',
            'description': 'ent_summary',
            'published date': 'ent_start',
            'publisher_href': 'contentOriginUrl',
            'publisher_title': 'ent_press_name'
        })

        df['ent_start'] = pd.to_datetime(df['ent_start'], format='%a, %d %b %Y %H:%M:%S %Z', errors='coerce')
        df['ent_start'] = df['ent_start'].dt.strftime('%Y-%m-%d')
        df['ent_print_type'] = 'news'

    # Poner el folder donde se van a guardar las noticias
        df.to_csv("unprocessed_press/" + keyword + "_press_" + start_date_str + " to "+ end_date_str + ".csv", index=False)

        timestamp = fx_timestamp()
        num_records = len(df)
        print('Records for '+ keyword + ': ' + str(num_records) + ' fetched at '+ timestamp )

        return df, num_records

# %%
keyword = 'Tesla, inc'
start_date = '2024-01-01' #2017-08-22 formato
end_date = '2024-12-31'
sparseness = 3

df_press = split_date_range_and_process(keyword, start_date, end_date, sparseness)
df_press

# %%
# Este bloque de código sirve para juntar todos los archivos en uno y poder empezar a extraer el URL original

folder_path = "unprocessed_press"  # carpeta donde están los CSVs descargados
subject = "Tesla, inc"  # usar el nombre que se usó como keyword

# Listar todos los archivos CSV relevantes para el subject
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv") and subject in f]

# Leer y juntar todos los archivos
df_list = []
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    df_list.append(df)

# Concatenar todos los DataFrames
df_combined = pd.concat(df_list, ignore_index=True)

print(f"Archivos combinados: {len(csv_files)}")
print(f"Total de noticias combinadas: {len(df_combined)}")

# %% [markdown]
# ### URL original

# %% [markdown]
# El método previo para obtener las noticias nos da un URL en formato RSS (Really Simple Syndication). Esto quiere decir que necesitamos ir más allá para poder realizar la extracción del texto y posterior análisis de sentimiento. Cabe precisar que, este método toma varios segundos por fila y, por ende, se opta por trabajarlo por batch de 1000 filas lo cual dura aproximadamente 1 hora y 30 minutos por año.

# %%
# Borrar duplicados en base al 'title' y 'publish_date'

df = df_combined
df = df.drop_duplicates(subset=["title", "publish_date"])
df = df.reset_index(drop=True)

print(f"Duplicados borrados. Tamaño del DF: {df.shape}")

# %%
# Funcion para decodificar el RSS
def get_original_url(source_url):
    interval_time = 5
    try:
        decoded_url = new_decoderv1(source_url, interval=interval_time)
        if decoded_url.get("status"):
            return decoded_url["decoded_url"]
        else:
            return source_url
    except Exception as e:
        print(f"⚠️ Error occurred with {source_url}: {e}")
        return None

# Cargar data
df = pd.read_csv("tesla_inc_unprocessed_press_filtered.csv")
df['ent_start'] = pd.to_datetime(df['ent_start'], errors='coerce')

# Filtrar por 2019
df_2019 = df[df['ent_start'].dt.year == 2019].copy()
print(f"📅 Processing {len(df_2019)} rows from 2019")

# Crear el folder donde se van a guardar los batches
output_folder = "batches_2021_tesla"
os.makedirs(output_folder, exist_ok=True)

# El proceso toma mucho tiempo, por ende, se realiza el procesamiento en batches de 1000.
batch_size = 1000
num_batches = (len(df_2019) // batch_size) + 1

# Procesamiento
for batch_num in range(num_batches):
    start = batch_num * batch_size
    end = min((batch_num + 1) * batch_size, len(df_2019))
    batch_df = df_2019.iloc[start:end].copy()

    print(f"🔄 Batch {batch_num + 1}/{num_batches}: Rows {start} to {end}")

    # Utilizamiento de swifter para que sea más rápido (procesamiento paralelo de manera automática cuando es posible)
    tqdm.pandas(desc=f"Batch {batch_num + 1} decoding")
    batch_df['expanded_url'] = batch_df['url'].swifter.apply(get_original_url)

    # Guardar al CSV
    output_file = f"{output_folder}/2019_tesla_batch_{batch_num + 1}.csv"
    batch_df.to_csv(output_file, index=False)
    print(f"✅ Saved batch {batch_num + 1} to {output_file}\n")
# Out:
# 📅 Processing 1216 rows from 2019
# 🔄 Batch 1/2: Rows 0 to 1000
# Pandas Apply:   0%|          | 0/1000 [00:00<?, ?it/s]
# ✅ Saved batch 1 to batches_2021_apple/2019_apple_batch_1.csv
#
# 🔄 Batch 2/2: Rows 1000 to 1216
# Pandas Apply:   0%|          | 0/216 [00:00<?, ?it/s]
# ✅ Saved batch 2 to batches_2021_apple/2019_apple_batch_2.csv

# %%
# Este bloque del código sirve para juntar todos los archivos en uno y poder realizar el análisis de sentimiento

FOLDER_PATH = "batches_2021_tesla"
OUTPUT_FILE = "combined_batches.csv"

all_files = list(Path(FOLDER_PATH).glob("*.csv"))
if not all_files:
    print(f"No se encontrar archivos CSV {FOLDER_PATH}")
else:
    df_list = []
    for file in all_files:
        try:
            df = pd.read_csv(file)
            df_list.append(df)
        except Exception as e:
            print(f"Fallo al leer {file.name}: {e}")

    if df_list:
        combined_df = pd.concat(df_list, ignore_index=True)
        combined_df.to_csv(OUTPUT_FILE, index=False)
        print(f"Combinar {len(df_list)} archivos en '{OUTPUT_FILE}'")
    else:
        print("No hay CSV válidos para combinar")
# Out:
# ✅ Combined 20 files into 'combined_batches.csv'

# %% [markdown]
# ### Resumen de la noticia

# %% [markdown]
# Posterior a obtener el link original de la noticia obtenida, se procede a borrar duplicados y a realizar el doble click en dicho link, con el fin de extraer un resumen que será posteriormente analizado para determinar el sentimiento asociado a la noticia. Sin embargo, se identifica un problema con algunas webs que detectan al código como si fuese un robot. Para estas noticias donde no es posible obtener el resumen de la noticia, se opta por utilizar el título de la misma.

# %%
df = pd.read_csv("combined_batches.csv")

# %%
df = df[['ent_name', 'ent_start', 'url', 'ent_press_name', 'expanded_url']]

# %%
df = df.rename(columns={
    "ent_name": "title",
    "ent_start": "publish_date",
    "ent_press_name": "source",
})

# %%
df.head(1)
# Out:
#                                                title publish_date  \
# 0  Wall Street sinks as hopes wane for tariff del...   2025-04-08
#
#                                                  url              source  \
# 0  https://news.google.com/rss/articles/CBMixwFBV...  marketscreener.com
#
#                                         expanded_url
# 0  https://www.marketscreener.com/quote/stock/APP...

# %%
# Parámetros
OUTPUT_DIR = "summary_tesla_folder"
BATCH_SIZE = 1000

# Crear la carpeta del parámetro si es que no existe
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Se utiliza el tqdm para poder seguir el progreso que vamos teniendo
tqdm.pandas(desc="Generando resúmenes")

# Función para obtener los resúmenes
def get_summary(url):
    try:
        article = Article(url)
        article.download()
        article.parse()
        article.nlp()
        return article.summary
    except Exception as e:
        print(f"Falló extraer el resumen {url} porque {e}")
        return None

# Procesamiento en batches
num_batches = (len(df) // BATCH_SIZE) + 1

for i in range(num_batches):
    start = i * BATCH_SIZE
    end = min((i + 1) * BATCH_SIZE, len(df))
    batch = df.iloc[start:end].copy()

    print(f"\n Procesando el batch {i+1}/{num_batches} (filas {start}–{end})...")

    batch['summary'] = batch['expanded_url'].progress_apply(get_summary)

    output_path = os.path.join(OUTPUT_DIR, f"tesla_summary_batch_{i+1}.csv")
    batch.to_csv(output_path, index=False)
    print(f"✅ Saved batch {i+1} to {output_path}")
# Out:
# 📦 Processing batch 1/17 (rows 0–1000)...
# 📰 Generating Summaries:   0%|          | 0/1000 [00:00<?, ?it/s]
# ⚠️ Failed to extract summary from https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Wall-Street-sinks-as-hopes-wane-for-tariff-delays-deals-49566588/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Wall-Street-sinks-as-hopes-wane-for-tariff-delays-deals-49566588/ on URL https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Wall-Street-sinks-as-hopes-wane-for-tariff-delays-deals-49566588/
# ⚠️ Failed to extract summary from https://m.uk.investing.com/news/-4021762?ampMode=1 because Article `download()` failed with 403 Client Error: Forbidden for url: https://m.uk.investing.com/news/-4021762?ampMode=1 on URL https://m.uk.investing.com/news/-4021762?ampMode=1
# ⚠️ Failed to extract summary from https://m.ng.investing.com/news/stock-market-news/apple-stock-hits-11mth-low-on-tariff-fears-falls-behind-microsoft-in-market-cap-1857223?ampMode=1 because Article `download()` failed with 403 Client Error: Forbidden for url: https://m.ng.investing.com/news/stock-market-news/apple-stock-hits-11mth-low-on-tariff-fears-falls-behind-microsoft-in-market-cap-1857223?ampMode=1 on URL https://m.ng.investing.com/news/stock-market-news/apple-stock-hits-11mth-low-on-tariff-fears-falls-behind-microsoft-in-market-cap-1857223?ampMode=1
# ⚠️ Failed to extract summary from https://m.in.investing.com/news/-4765539?ampMode=1 because Article `download()` failed with 403 Client Error: Forbidden for url: https://m.in.investing.com/news/-4765539?ampMode=1 on URL https://m.in.investing.com/news/-4765539?ampMode=1
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/04/08/5th-street-advisors-llc-has-2-96-million-position-in-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/04/08/5th-street-advisors-llc-has-2-96-million-position-in-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/04/08/5th-street-advisors-llc-has-2-96-million-position-in-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/04/08/bsn-capital-partners-ltd-grows-stake-in-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/04/08/bsn-capital-partners-ltd-grows-stake-in-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/04/08/bsn-capital-partners-ltd-grows-stake-in-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.inc.com/associated-press/apple-shareholders-reject-proposal-to-scrap-diversity-programs/91152482 because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.inc.com/associated-press/apple-shareholders-reject-proposal-to-scrap-diversity-programs/91152482 on URL https://www.inc.com/associated-press/apple-shareholders-reject-proposal-to-scrap-diversity-programs/91152482
# ⚠️ Failed to extract summary from https://www.advisorperspectives.com/articles/2025/02/24/apple-add-20-000-us-jobs-threat-trump-tariffs?firm=bloomberg-news because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.advisorperspectives.com/articles/2025/02/24/apple-add-20-000-us-jobs-threat-trump-tariffs?firm=bloomberg-news on URL https://www.advisorperspectives.com/articles/2025/02/24/apple-add-20-000-us-jobs-threat-trump-tariffs?firm=bloomberg-news
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/newsletters/2025-03-24/apple-airpods-fast-pairing-is-targeted-by-eu-antitrust-regulators because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/newsletters/2025-03-24/apple-airpods-fast-pairing-is-targeted-by-eu-antitrust-regulators on URL https://www.bloomberg.com/news/newsletters/2025-03-24/apple-airpods-fast-pairing-is-targeted-by-eu-antitrust-regulators
# ⚠️ Failed to extract summary from https://seekingalpha.com/article/4770109-apple-stock-buy-now-before-the-iphone-17-hype because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/article/4770109-apple-stock-buy-now-before-the-iphone-17-hype on URL https://seekingalpha.com/article/4770109-apple-stock-buy-now-before-the-iphone-17-hype
# ⚠️ Failed to extract summary from https://siliconangle.com/2025/03/25/apple-host-wwdc-2025-june-9-13-os-upgrades-expected/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://siliconangle.com/2025/03/25/apple-host-wwdc-2025-june-9-13-os-upgrades-expected/ on URL https://siliconangle.com/2025/03/25/apple-host-wwdc-2025-june-9-13-os-upgrades-expected/
# ⚠️ Failed to extract summary from https://www.reuters.com/technology/apple-announces-99-million-new-clean-energy-fund-china-2025-03-24/ because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/apple-announces-99-million-new-clean-energy-fund-china-2025-03-24/ on URL https://www.reuters.com/technology/apple-announces-99-million-new-clean-energy-fund-china-2025-03-24/
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-03-25/apple-poised-to-unveil-new-software-at-june-9-developers-event because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-03-25/apple-poised-to-unveil-new-software-at-june-9-developers-event on URL https://www.bloomberg.com/news/articles/2025-03-25/apple-poised-to-unveil-new-software-at-june-9-developers-event
# ⚠️ Failed to extract summary from https://seekingalpha.com/article/4769858-apple-the-ultimate-capital-return-play-rating-upgrade because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/article/4769858-apple-the-ultimate-capital-return-play-rating-upgrade on URL https://seekingalpha.com/article/4769858-apple-the-ultimate-capital-return-play-rating-upgrade
# ⚠️ Failed to extract summary from https://www.reuters.com/technology/eu-set-close-investigation-into-apples-browser-options-sources-say-2025-03-25/ because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/eu-set-close-investigation-into-apples-browser-options-sources-say-2025-03-25/ on URL https://www.reuters.com/technology/eu-set-close-investigation-into-apples-browser-options-sources-say-2025-03-25/
# ⚠️ Failed to extract summary from https://english.alarabiya.net/business/technology/2025/03/24/apple-announces-99-million-new-clean-energy-fund-in-china because Article `download()` failed with 403 Client Error: Forbidden for url: https://english.alarabiya.net/business/technology/2025/03/24/apple-announces-99-million-new-clean-energy-fund-in-china on URL https://english.alarabiya.net/business/technology/2025/03/24/apple-announces-99-million-new-clean-energy-fund-in-china
# ⚠️ Failed to extract summary from https://seekingalpha.com/article/4769862-apple-stock-heres-the-looming-threat-no-ones-talking-about because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/article/4769862-apple-stock-heres-the-looming-threat-no-ones-talking-about on URL https://seekingalpha.com/article/4769862-apple-stock-heres-the-looming-threat-no-ones-talking-about
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4423891-apple-launches-new-99-million-investment-fund-to-accelerate-clean-energy-development-in-china because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4423891-apple-launches-new-99-million-investment-fund-to-accelerate-clean-energy-development-in-china on URL https://seekingalpha.com/news/4423891-apple-launches-new-99-million-investment-fund-to-accelerate-clean-energy-development-in-china
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4424910-apple-sets-june-9-as-kickoff-for-annual-worldwide-developer-conference because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4424910-apple-sets-june-9-as-kickoff-for-annual-worldwide-developer-conference on URL https://seekingalpha.com/news/4424910-apple-sets-june-9-as-kickoff-for-annual-worldwide-developer-conference
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4424209-apple-ceo-cook-praises-deepseek-on-visit-to-china-calls-ai-models-excellent because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4424209-apple-ceo-cook-praises-deepseek-on-visit-to-china-calls-ai-models-excellent on URL https://seekingalpha.com/news/4424209-apple-ceo-cook-praises-deepseek-on-visit-to-china-calls-ai-models-excellent
# ⚠️ Failed to extract summary from https://seekingalpha.com/article/4769910-apple-upgrade-super-cycle-dream-turns-into-nightmare because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/article/4769910-apple-upgrade-super-cycle-dream-turns-into-nightmare on URL https://seekingalpha.com/article/4769910-apple-upgrade-super-cycle-dream-turns-into-nightmare
# ⚠️ Failed to extract summary from https://www.bizjournals.com/twincities/news/2025/03/25/developer-buys-uptown-apple-store-minneapolis.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bizjournals.com/twincities/news/2025/03/25/developer-buys-uptown-apple-store-minneapolis.html on URL https://www.bizjournals.com/twincities/news/2025/03/25/developer-buys-uptown-apple-store-minneapolis.html
# ⚠️ Failed to extract summary from https://seekingalpha.com/article/4769908-apple-minimal-growth-and-innovation-left-no-longer-magnificent-here because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/article/4769908-apple-minimal-growth-and-innovation-left-no-longer-magnificent-here on URL https://seekingalpha.com/article/4769908-apple-minimal-growth-and-innovation-left-no-longer-magnificent-here
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4424165-apple-iphone-shipments-to-china-drop-in-january-jefferies-expects-declines-through-1q25 because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4424165-apple-iphone-shipments-to-china-drop-in-january-jefferies-expects-declines-through-1q25 on URL https://seekingalpha.com/news/4424165-apple-iphone-shipments-to-china-drop-in-january-jefferies-expects-declines-through-1q25
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4424810-apple-ceo-cook-reaffirms-chinas-wuthering-waves-coming-to-mac-during-visit because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4424810-apple-ceo-cook-reaffirms-chinas-wuthering-waves-coming-to-mac-during-visit on URL https://seekingalpha.com/news/4424810-apple-ceo-cook-reaffirms-chinas-wuthering-waves-coming-to-mac-during-visit
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4423883-apple-eyes-cameras-smartwatches-ai-features because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4423883-apple-eyes-cameras-smartwatches-ai-features on URL https://seekingalpha.com/news/4423883-apple-eyes-cameras-smartwatches-ai-features
# ⚠️ Failed to extract summary from https://www.patentlyapple.com/2025/03/apple-is-set-to-stave-off-eu-fines-over-browser-options-by-complying-with-dma-rules.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.patentlyapple.com/2025/03/apple-is-set-to-stave-off-eu-fines-over-browser-options-by-complying-with-dma-rules.html on URL https://www.patentlyapple.com/2025/03/apple-is-set-to-stave-off-eu-fines-over-browser-options-by-complying-with-dma-rules.html
# ⚠️ Failed to extract summary from https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/First-quarter-US-earnings-outlook-looks-less-rosy-with-tariff-worries-in-focus-49412634/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/First-quarter-US-earnings-outlook-looks-less-rosy-with-tariff-worries-in-focus-49412634/ on URL https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/First-quarter-US-earnings-outlook-looks-less-rosy-with-tariff-worries-in-focus-49412634/
# ⚠️ Failed to extract summary from https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-s-AI-Pivot-49424395/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-s-AI-Pivot-49424395/ on URL https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-s-AI-Pivot-49424395/
# ⚠️ Failed to extract summary from http://www.corydontimes.com/news/national/twitter-logo-once-on-company-s-headquarters-sold-for-nearly-35-000/article_589cea85-c555-5ba4-86f1-5eeedf34f404.html because Article `download()` failed with 429 Client Error: Too Many Requests for url: http://www.corydontimes.com/news/national/twitter-logo-once-on-company-s-headquarters-sold-for-nearly-35-000/article_589cea85-c555-5ba4-86f1-5eeedf34f404.html on URL http://www.corydontimes.com/news/national/twitter-logo-once-on-company-s-headquarters-sold-for-nearly-35-000/article_589cea85-c555-5ba4-86f1-5eeedf34f404.html
# ⚠️ Failed to extract summary from https://www.moorenews.com/news/national/twitter-logo-once-on-company-s-headquarters-sold-for-nearly-35-000/article_ee7f4dd4-974e-5fc8-bcc6-23753d11ea69.html because Article `download()` failed with 429 Client Error: Too Many Requests for url: https://www.moorenews.com/news/national/twitter-logo-once-on-company-s-headquarters-sold-for-nearly-35-000/article_ee7f4dd4-974e-5fc8-bcc6-23753d11ea69.html on URL https://www.moorenews.com/news/national/twitter-logo-once-on-company-s-headquarters-sold-for-nearly-35-000/article_ee7f4dd4-974e-5fc8-bcc6-23753d11ea69.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-is-forsta-ap-fondens-largest-position.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-is-forsta-ap-fondens-largest-position.html on URL https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-is-forsta-ap-fondens-largest-position.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-shares-bought-by-nvest-financial-llc.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-shares-bought-by-nvest-financial-llc.html on URL https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-shares-bought-by-nvest-financial-llc.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-is-strategic-blueprint-llcs-5th-largest-position.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-is-strategic-blueprint-llcs-5th-largest-position.html on URL https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-is-strategic-blueprint-llcs-5th-largest-position.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/25/wade-financial-advisory-inc-has-4-08-million-stock-position-in-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/25/wade-financial-advisory-inc-has-4-08-million-stock-position-in-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/25/wade-financial-advisory-inc-has-4-08-million-stock-position-in-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-shares-acquired-by-invesco-llc.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-shares-acquired-by-invesco-llc.html on URL https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-shares-acquired-by-invesco-llc.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-shares-sold-by-hantz-financial-services-inc.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-shares-sold-by-hantz-financial-services-inc.html on URL https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-shares-sold-by-hantz-financial-services-inc.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/25/applied-capital-llc-sells-78-shares-of-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/25/applied-capital-llc-sells-78-shares-of-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/25/applied-capital-llc-sells-78-shares-of-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/25/plimoth-trust-co-llc-has-27-75-million-stock-holdings-in-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/25/plimoth-trust-co-llc-has-27-75-million-stock-holdings-in-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/25/plimoth-trust-co-llc-has-27-75-million-stock-holdings-in-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/24/libra-wealth-llc-has-6-64-million-holdings-in-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/24/libra-wealth-llc-has-6-64-million-holdings-in-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/24/libra-wealth-llc-has-6-64-million-holdings-in-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/25/swedbank-ab-has-4-69-billion-stake-in-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/25/swedbank-ab-has-4-69-billion-stake-in-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/25/swedbank-ab-has-4-69-billion-stake-in-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-is-smith-group-asset-management-llcs-largest-position.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-is-smith-group-asset-management-llcs-largest-position.html on URL https://www.defenseworld.net/2025/03/25/apple-inc-nasdaqaapl-is-smith-group-asset-management-llcs-largest-position.html
# ⚠️ Failed to extract summary from https://reporter.am/2025/03/24/apple-inc-nasdaqaapl-is-williams-novak-llcs-6th-largest-position.html because Article `download()` failed with 404 Client Error: Not Found for url: https://reporter.am/2025/03/24/apple-inc-nasdaqaapl-is-williams-novak-llcs-6th-largest-position.html on URL https://reporter.am/2025/03/24/apple-inc-nasdaqaapl-is-williams-novak-llcs-6th-largest-position.html
# ⚠️ Failed to extract summary from https://tradersunion.com/news/financial-news/show/170203-apple-stock-shows-minor-growth/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://tradersunion.com/news/financial-news/show/170203-apple-stock-shows-minor-growth/ on URL https://tradersunion.com/news/financial-news/show/170203-apple-stock-shows-minor-growth/
# ⚠️ Failed to extract summary from https://www.reuters.com/technology/apple-finds-little-sympathy-german-judges-antitrust-appeal-2025-01-28/ because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/apple-finds-little-sympathy-german-judges-antitrust-appeal-2025-01-28/ on URL https://www.reuters.com/technology/apple-finds-little-sympathy-german-judges-antitrust-appeal-2025-01-28/
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-01-28/apple-may-lose-suit-against-broader-german-antitrust-scrutiny because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-01-28/apple-may-lose-suit-against-broader-german-antitrust-scrutiny on URL https://www.bloomberg.com/news/articles/2025-01-28/apple-may-lose-suit-against-broader-german-antitrust-scrutiny
# ⚠️ Failed to extract summary from https://www.patentlyapple.com/2025/01/german-federal-judges-have-signaled-that-they-could-back-the-countrys-antitrust-regulator-against-apple.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.patentlyapple.com/2025/01/german-federal-judges-have-signaled-that-they-could-back-the-countrys-antitrust-regulator-against-apple.html on URL https://www.patentlyapple.com/2025/01/german-federal-judges-have-signaled-that-they-could-back-the-countrys-antitrust-regulator-against-apple.html
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/features/2025-01-28/huawei-harmonyos-next-review-new-phone-seeks-to-break-apple-google-dominance because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/features/2025-01-28/huawei-harmonyos-next-review-new-phone-seeks-to-break-apple-google-dominance on URL https://www.bloomberg.com/news/features/2025-01-28/huawei-harmonyos-next-review-new-phone-seeks-to-break-apple-google-dominance
# ⚠️ Failed to extract summary from https://www.techrepublic.com/article/apple-operating-system-revamp/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.techrepublic.com/article/apple-operating-system-revamp/ on URL https://www.techrepublic.com/article/apple-operating-system-revamp/
# ⚠️ Failed to extract summary from https://www.inc.com/kit-eaton/apple-paused-a-big-update-to-siri-and-fessed-up-to-its-woes-its-a-lesson-for-all-innovators/91159454 because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.inc.com/kit-eaton/apple-paused-a-big-update-to-siri-and-fessed-up-to-its-woes-its-a-lesson-for-all-innovators/91159454 on URL https://www.inc.com/kit-eaton/apple-paused-a-big-update-to-siri-and-fessed-up-to-its-woes-its-a-lesson-for-all-innovators/91159454
# ⚠️ Failed to extract summary from https://www.fastcompany.com/91294577/what-the-break-up-of-google-could-mean-for-apple-and-other-tech-companies because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.fastcompany.com/91294577/what-the-break-up-of-google-could-mean-for-apple-and-other-tech-companies on URL https://www.fastcompany.com/91294577/what-the-break-up-of-google-could-mean-for-apple-and-other-tech-companies
# ⚠️ Failed to extract summary from https://seekingalpha.com/article/4766643-eve-ate-the-apple-and-im-biting-upgrading-apple-to-a-strong-buy because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/article/4766643-eve-ate-the-apple-and-im-biting-upgrading-apple-to-a-strong-buy on URL https://seekingalpha.com/article/4766643-eve-ate-the-apple-and-im-biting-upgrading-apple-to-a-strong-buy
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4419372-apple-leads-decline-in-global-smartwatch-shipments-in-2024-counterpoint because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4419372-apple-leads-decline-in-global-smartwatch-shipments-in-2024-counterpoint on URL https://seekingalpha.com/news/4419372-apple-leads-decline-in-global-smartwatch-shipments-in-2024-counterpoint
# ⚠️ Failed to extract summary from https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-to-Overhaul-Software-for-iOS-19-iPadOS-19-macOS-16-49301851/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-to-Overhaul-Software-for-iOS-19-iPadOS-19-macOS-16-49301851/ on URL https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-to-Overhaul-Software-for-iOS-19-iPadOS-19-macOS-16-49301851/
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-03-11/metallica-to-debut-immersive-concert-film-on-apple-vision-pro because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-03-11/metallica-to-debut-immersive-concert-film-on-apple-vision-pro on URL https://www.bloomberg.com/news/articles/2025-03-11/metallica-to-debut-immersive-concert-film-on-apple-vision-pro
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4419042-apple-plans-to-revamp-operating-system-with-ios-19-report?source=generic_rss because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4419042-apple-plans-to-revamp-operating-system-with-ios-19-report?source=generic_rss on URL https://seekingalpha.com/news/4419042-apple-plans-to-revamp-operating-system-with-ios-19-report?source=generic_rss
# ⚠️ Failed to extract summary from https://www.investing.com/academy/stock-picks/largest-market-cap-companies/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.investing.com/academy/stock-picks/largest-market-cap-companies/ on URL https://www.investing.com/academy/stock-picks/largest-market-cap-companies/
# ⚠️ Failed to extract summary from https://www.proactiveinvestors.co.uk/companies/news/1067643 because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.proactiveinvestors.co.uk/companies/news/1067643 on URL https://www.proactiveinvestors.co.uk/companies/news/1067643
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/11/ade-llc-purchases-74-shares-of-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/11/ade-llc-purchases-74-shares-of-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/11/ade-llc-purchases-74-shares-of-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/11/apple-inc-nasdaqaapl-shares-sold-by-act-wealth-management-llc.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/11/apple-inc-nasdaqaapl-shares-sold-by-act-wealth-management-llc.html on URL https://www.defenseworld.net/2025/03/11/apple-inc-nasdaqaapl-shares-sold-by-act-wealth-management-llc.html
# ⚠️ Failed to extract summary from https://www.reuters.com/technology/apple-loses-german-antitrust-appeal-opening-door-greater-controls-2025-03-18/ because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/apple-loses-german-antitrust-appeal-opening-door-greater-controls-2025-03-18/ on URL https://www.reuters.com/technology/apple-loses-german-antitrust-appeal-opening-door-greater-controls-2025-03-18/
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-03-18/apple-loses-top-court-fight-against-german-antitrust-crackdown because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-03-18/apple-loses-top-court-fight-against-german-antitrust-crackdown on URL https://www.bloomberg.com/news/articles/2025-03-18/apple-loses-top-court-fight-against-german-antitrust-crackdown
# ⚠️ Failed to extract summary from https://www.thestreet.com/investing/tim-cook-net-worth-apple-ceo because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.thestreet.com/investing/tim-cook-net-worth-apple-ceo on URL https://www.thestreet.com/investing/tim-cook-net-worth-apple-ceo
# ⚠️ Failed to extract summary from https://seekingalpha.com/article/4768628-apple-stock-siri-delay-problem because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/article/4768628-apple-stock-siri-delay-problem on URL https://seekingalpha.com/article/4768628-apple-stock-siri-delay-problem
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-03-18/smartwatch-pioneer-pebble-relaunches-with-apple-watch-alternative because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-03-18/smartwatch-pioneer-pebble-relaunches-with-apple-watch-alternative on URL https://www.bloomberg.com/news/articles/2025-03-18/smartwatch-pioneer-pebble-relaunches-with-apple-watch-alternative
# ⚠️ Failed to extract summary from https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/APPLE-INC-Goldman-Sachs-reiterates-its-Buy-rating-49361298/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/APPLE-INC-Goldman-Sachs-reiterates-its-Buy-rating-49361298/ on URL https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/APPLE-INC-Goldman-Sachs-reiterates-its-Buy-rating-49361298/
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4421702-apple-well-positioned-for-double-digit-earnings-growth-through-2029-evercore because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4421702-apple-well-positioned-for-double-digit-earnings-growth-through-2029-evercore on URL https://seekingalpha.com/news/4421702-apple-well-positioned-for-double-digit-earnings-growth-through-2029-evercore
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-03-18/apple-loses-top-court-fight-against-german-antitrust-crackdown?srnd=phx-technology because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-03-18/apple-loses-top-court-fight-against-german-antitrust-crackdown?srnd=phx-technology on URL https://www.bloomberg.com/news/articles/2025-03-18/apple-loses-top-court-fight-against-german-antitrust-crackdown?srnd=phx-technology
# ⚠️ Failed to extract summary from https://www.investing.com/news/analyst-ratings/evercore-isi-lifts-apple-stock-price-target-to-275-93CH-3933731 because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.investing.com/news/analyst-ratings/evercore-isi-lifts-apple-stock-price-target-to-275-93CH-3933731 on URL https://www.investing.com/news/analyst-ratings/evercore-isi-lifts-apple-stock-price-target-to-275-93CH-3933731
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4421644-apple-loses-antitrust-appeal-in-german-court because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4421644-apple-loses-antitrust-appeal-in-german-court on URL https://seekingalpha.com/news/4421644-apple-loses-antitrust-appeal-in-german-court
# ⚠️ Failed to extract summary from https://www.benzinga.com/insights/options/25/03/44379089/this-is-what-whales-are-betting-on-apple because Article `download()` failed with 429 Client Error: Too Many Requests for url: https://www.benzinga.com/insights/options/25/03/44379089/this-is-what-whales-are-betting-on-apple on URL https://www.benzinga.com/insights/options/25/03/44379089/this-is-what-whales-are-betting-on-apple
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/19/park-edge-advisors-llc-acquires-1380-shares-of-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/19/park-edge-advisors-llc-acquires-1380-shares-of-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/19/park-edge-advisors-llc-acquires-1380-shares-of-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/18/affiance-financial-llc-acquires-669-shares-of-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/18/affiance-financial-llc-acquires-669-shares-of-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/18/affiance-financial-llc-acquires-669-shares-of-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/19/novare-capital-management-llc-sells-834-shares-of-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/19/novare-capital-management-llc-sells-834-shares-of-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/19/novare-capital-management-llc-sells-834-shares-of-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.forex.com/en-us/trading-guides/apple-acquisition-history/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.forex.com/en-us/trading-guides/apple-acquisition-history/ on URL https://www.forex.com/en-us/trading-guides/apple-acquisition-history/
# ⚠️ Failed to extract summary from https://www.thestreet.com/technology/mark-zuckerbergs-facebook-instagram-block-new-apple-product because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.thestreet.com/technology/mark-zuckerbergs-facebook-instagram-block-new-apple-product on URL https://www.thestreet.com/technology/mark-zuckerbergs-facebook-instagram-block-new-apple-product
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4432531-notable-analyst-calls-this-week-apple-gm-and-comcast-stocks-among-top-picks because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4432531-notable-analyst-calls-this-week-apple-gm-and-comcast-stocks-among-top-picks on URL https://seekingalpha.com/news/4432531-notable-analyst-calls-this-week-apple-gm-and-comcast-stocks-among-top-picks
# ⚠️ Failed to extract summary from https://newsghana.com.gh/apples-supply-chain-remains-tethered-to-china-despite-diversification-push/ because Article `download()` failed with HTTPSConnectionPool(host='newsghana.com.gh', port=443): Read timed out. (read timeout=7) on URL https://newsghana.com.gh/apples-supply-chain-remains-tethered-to-china-despite-diversification-push/
# ⚠️ Failed to extract summary from https://www.marketwatch.com/story/apples-stock-may-see-its-worst-day-since-since-2022-here-are-2-major-worries-42fe0edb because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/story/apples-stock-may-see-its-worst-day-since-since-2022-here-are-2-major-worries-42fe0edb on URL https://www.marketwatch.com/story/apples-stock-may-see-its-worst-day-since-since-2022-here-are-2-major-worries-42fe0edb
# ⚠️ Failed to extract summary from https://www.proactiveinvestors.com/companies/news/1067643/apple-new-product-launches-to-support-revenue-growth-and-buy-case-says-wall-street-bank-1067643.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.proactiveinvestors.com/companies/news/1067643/apple-new-product-launches-to-support-revenue-growth-and-buy-case-says-wall-street-bank-1067643.html on URL https://www.proactiveinvestors.com/companies/news/1067643/apple-new-product-launches-to-support-revenue-growth-and-buy-case-says-wall-street-bank-1067643.html
# ⚠️ Failed to extract summary from https://www.reuters.com/technology/eu-likely-impose-modest-fines-apple-meta-over-dma-breaches-sources-say-2025-03-10/ because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/eu-likely-impose-modest-fines-apple-meta-over-dma-breaches-sources-say-2025-03-10/ on URL https://www.reuters.com/technology/eu-likely-impose-modest-fines-apple-meta-over-dma-breaches-sources-say-2025-03-10/
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4418953-google-apple-search-payment-deal-could-be-at-risk-analysts-warn because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4418953-google-apple-search-payment-deal-could-be-at-risk-analysts-warn on URL https://seekingalpha.com/news/4418953-google-apple-search-payment-deal-could-be-at-risk-analysts-warn
# ⚠️ Failed to extract summary from https://www.marketwatch.com/story/apple-and-nvidia-led-mondays-750-billion-tech-wreck-how-to-play-the-aftermath-66604244 because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/story/apple-and-nvidia-led-mondays-750-billion-tech-wreck-how-to-play-the-aftermath-66604244 on URL https://www.marketwatch.com/story/apple-and-nvidia-led-mondays-750-billion-tech-wreck-how-to-play-the-aftermath-66604244
# ⚠️ Failed to extract summary from https://www.thestreet.com/investing/surprising-iphone-problem-sends-apple-stock-reeling because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.thestreet.com/investing/surprising-iphone-problem-sends-apple-stock-reeling on URL https://www.thestreet.com/investing/surprising-iphone-problem-sends-apple-stock-reeling
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4418922-apple-2025-iphone-shipment-estimate-lowered-by-citi-on-siri-upgrade-delay because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4418922-apple-2025-iphone-shipment-estimate-lowered-by-citi-on-siri-upgrade-delay on URL https://seekingalpha.com/news/4418922-apple-2025-iphone-shipment-estimate-lowered-by-citi-on-siri-upgrade-delay
# ⚠️ Failed to extract summary from https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-preparing-for-a-major-software-overhaul-Bloomberg-News-reports-49289387/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-preparing-for-a-major-software-overhaul-Bloomberg-News-reports-49289387/ on URL https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-preparing-for-a-major-software-overhaul-Bloomberg-News-reports-49289387/
# ⚠️ Failed to extract summary from https://www.reuters.com/technology/apple-preparing-major-software-overhaul-bloomberg-news-reports-2025-03-10/ because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/apple-preparing-major-software-overhaul-bloomberg-news-reports-2025-03-10/ on URL https://www.reuters.com/technology/apple-preparing-major-software-overhaul-bloomberg-news-reports-2025-03-10/
# ⚠️ Failed to extract summary from https://www.inc.com/jason-aten/the-m3-ipad-air-is-unsurprisingly-good/91158658 because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.inc.com/jason-aten/the-m3-ipad-air-is-unsurprisingly-good/91158658 on URL https://www.inc.com/jason-aten/the-m3-ipad-air-is-unsurprisingly-good/91158658
# ⚠️ Failed to extract summary from https://macdailynews.com/2025/03/10/apple-preps-dramatic-operating-system-overhauls-for-iphone-mac-and-ipad/ because Article `download()` failed with HTTPSConnectionPool(host='macdailynews.com', port=443): Read timed out. (read timeout=7) on URL https://macdailynews.com/2025/03/10/apple-preps-dramatic-operating-system-overhauls-for-iphone-mac-and-ipad/
# ⚠️ Failed to extract summary from https://www.reuters.com/world/uk/britains-cma-says-big-tech-regulation-focus-uk-impact-will-issue-road-map-2025-03-10/ because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/world/uk/britains-cma-says-big-tech-regulation-focus-uk-impact-will-issue-road-map-2025-03-10/ on URL https://www.reuters.com/world/uk/britains-cma-says-big-tech-regulation-focus-uk-impact-will-issue-road-map-2025-03-10/
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-03-10/nasdaq-100-slumps-3-as-big-tech-rout-shows-no-signs-of-slowing-m836qgs5 because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-03-10/nasdaq-100-slumps-3-as-big-tech-rout-shows-no-signs-of-slowing-m836qgs5 on URL https://www.bloomberg.com/news/articles/2025-03-10/nasdaq-100-slumps-3-as-big-tech-rout-shows-no-signs-of-slowing-m836qgs5
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/10/apple-inc-nasdaqaapl-is-regent-peak-wealth-advisors-llcs-3rd-largest-position.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/10/apple-inc-nasdaqaapl-is-regent-peak-wealth-advisors-llcs-3rd-largest-position.html on URL https://www.defenseworld.net/2025/03/10/apple-inc-nasdaqaapl-is-regent-peak-wealth-advisors-llcs-3rd-largest-position.html
# ⚠️ Failed to extract summary from https://www.inc.com/reuters/after-95-million-settlement-apple-says-it-never-sold-data-from-siri/91105167 because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.inc.com/reuters/after-95-million-settlement-apple-says-it-never-sold-data-from-siri/91105167 on URL https://www.inc.com/reuters/after-95-million-settlement-apple-says-it-never-sold-data-from-siri/91105167
# ⚠️ Failed to extract summary from https://www.fastcompany.com/91257772/trump-inauguration-big-tech-donations-list-google-microsoft-meta-apple because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.fastcompany.com/91257772/trump-inauguration-big-tech-donations-list-google-microsoft-meta-apple on URL https://www.fastcompany.com/91257772/trump-inauguration-big-tech-donations-list-google-microsoft-meta-apple
# ⚠️ Failed to extract summary from https://www.inc.com/jason-aten/apple-says-it-is-fixing-ai-notification-summaries-it-missed-the-most-important-part/91104354 because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.inc.com/jason-aten/apple-says-it-is-fixing-ai-notification-summaries-it-missed-the-most-important-part/91104354 on URL https://www.inc.com/jason-aten/apple-says-it-is-fixing-ai-notification-summaries-it-missed-the-most-important-part/91104354
# ⚠️ Failed to extract summary from https://www.bloomberg.com/opinion/articles/2025-01-09/apple-iphone-16-battle-with-indonesia-is-not-over because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/opinion/articles/2025-01-09/apple-iphone-16-battle-with-indonesia-is-not-over on URL https://www.bloomberg.com/opinion/articles/2025-01-09/apple-iphone-16-battle-with-indonesia-is-not-over
# ⚠️ Failed to extract summary from https://www.proactiveinvestors.co.uk/companies/news/1063995/apple-says-siri-data-never-sold-after-agreeing-to-95mln-settlement-1063995.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.proactiveinvestors.co.uk/companies/news/1063995/apple-says-siri-data-never-sold-after-agreeing-to-95mln-settlement-1063995.html on URL https://www.proactiveinvestors.co.uk/companies/news/1063995/apple-says-siri-data-never-sold-after-agreeing-to-95mln-settlement-1063995.html
# ⚠️ Failed to extract summary from https://www.forbes.com/advisor/investing/best-blue-chip-stocks/ because Article `download()` failed with 403 Client Error: Max restarts limit reached for url: https://www.forbes.com/advisor/investing/best-blue-chip-stocks/ on URL https://www.forbes.com/advisor/investing/best-blue-chip-stocks/
# ⚠️ Failed to extract summary from http://www.thejakartapost.com/business/2025/01/08/govt-demands-apple-rd-to-end-iphone-sales-ban-but-takes-1b-investment.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.thejakartapost.com/business/2025/01/08/govt-demands-apple-rd-to-end-iphone-sales-ban-but-takes-1b-investment.html on URL http://www.thejakartapost.com/business/2025/01/08/govt-demands-apple-rd-to-end-iphone-sales-ban-but-takes-1b-investment.html
# ⚠️ Failed to extract summary from https://mainichi.jp/english/articles/20250108/p2g/00m/0na/044000c because Article `download()` failed with 403 Client Error: Forbidden for url: https://mainichi.jp/english/articles/20250108/p2g/00m/0na/044000c on URL https://mainichi.jp/english/articles/20250108/p2g/00m/0na/044000c
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/01/08/corda-investment-management-llc-sells-7348-shares-of-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/01/08/corda-investment-management-llc-sells-7348-shares-of-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/01/08/corda-investment-management-llc-sells-7348-shares-of-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.morningstar.com/sustainable-investing/what-expect-apples-annual-meeting-2 because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.morningstar.com/sustainable-investing/what-expect-apples-annual-meeting-2 on URL https://www.morningstar.com/sustainable-investing/what-expect-apples-annual-meeting-2
# ⚠️ Failed to extract summary from https://www.abc12.com/news/business/apple-launches-the-iphone-16e-a-cheaper-new-version-of-the-iphone-16/article_3b8621af-9bcb-5cb5-a991-03168429d81f.html because Article `download()` failed with 429 Client Error: Too Many Requests for url: https://www.abc12.com/news/business/apple-launches-the-iphone-16e-a-cheaper-new-version-of-the-iphone-16/article_3b8621af-9bcb-5cb5-a991-03168429d81f.html on URL https://www.abc12.com/news/business/apple-launches-the-iphone-16e-a-cheaper-new-version-of-the-iphone-16/article_3b8621af-9bcb-5cb5-a991-03168429d81f.html
# ⚠️ Failed to extract summary from https://news.az/news/iphone-16e-to-boost-apple-revenue-evercore-says because Article `download()` failed with 403 Client Error: Forbidden for url: https://news.az/news/iphone-16e-to-boost-apple-revenue-evercore-says on URL https://news.az/news/iphone-16e-to-boost-apple-revenue-evercore-says
# ⚠️ Failed to extract summary from https://www.patentlyapple.com/2025/02/a-new-apple-patent-describes-movable-optical-assemblies-for-hmds-to-accommodate-multiple-users-with-different-interpupillary.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.patentlyapple.com/2025/02/a-new-apple-patent-describes-movable-optical-assemblies-for-hmds-to-accommodate-multiple-users-with-different-interpupillary.html on URL https://www.patentlyapple.com/2025/02/a-new-apple-patent-describes-movable-optical-assemblies-for-hmds-to-accommodate-multiple-users-with-different-interpupillary.html
# ⚠️ Failed to extract summary from https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-s-iPhone-16E-Strategy-49118803/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-s-iPhone-16E-Strategy-49118803/ on URL https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-s-iPhone-16E-Strategy-49118803/
# ...
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-02-06/apple-s-china-focus-thrusts-it-into-center-of-geopolitical-fight because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-02-06/apple-s-china-focus-thrusts-it-into-center-of-geopolitical-fight on URL https://www.bloomberg.com/news/articles/2025-02-06/apple-s-china-focus-thrusts-it-into-center-of-geopolitical-fight
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/02/06/public-sector-pension-investment-board-buys-556375-shares-of-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/02/06/public-sector-pension-investment-board-buys-556375-shares-of-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/02/06/public-sector-pension-investment-board-buys-556375-shares-of-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/02/06/isthmus-partners-llc-lowers-holdings-in-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/02/06/isthmus-partners-llc-lowers-holdings-in-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/02/06/isthmus-partners-llc-lowers-holdings-in-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/02/05/worthpointe-llc-has-3-89-million-stake-in-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/02/05/worthpointe-llc-has-3-89-million-stake-in-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/02/05/worthpointe-llc-has-3-89-million-stake-in-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/02/05/apple-inc-nasdaqaapl-stock-position-boosted-by-bridgewater-associates-lp.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/02/05/apple-inc-nasdaqaapl-stock-position-boosted-by-bridgewater-associates-lp.html on URL https://www.defenseworld.net/2025/02/05/apple-inc-nasdaqaapl-stock-position-boosted-by-bridgewater-associates-lp.html
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-01-24/oracle-apple-google-diverge-on-whether-to-keep-serving-tiktok because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-01-24/oracle-apple-google-diverge-on-whether-to-keep-serving-tiktok on URL https://www.bloomberg.com/news/articles/2025-01-24/oracle-apple-google-diverge-on-whether-to-keep-serving-tiktok
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-02-19/apple-rolls-out-new-599-iphone-16e-in-bid-to-rekindle-growth because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-02-19/apple-rolls-out-new-599-iphone-16e-in-bid-to-rekindle-growth on URL https://www.bloomberg.com/news/articles/2025-02-19/apple-rolls-out-new-599-iphone-16e-in-bid-to-rekindle-growth
# ⚠️ Failed to extract summary from https://www.inc.com/jason-aten/apple-iphone-16e-just-killed-off-1-of-its-most-iconic-iphone-features/91149820 because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.inc.com/jason-aten/apple-iphone-16e-just-killed-off-1-of-its-most-iconic-iphone-features/91149820 on URL https://www.inc.com/jason-aten/apple-iphone-16e-just-killed-off-1-of-its-most-iconic-iphone-features/91149820
# ⚠️ Failed to extract summary from https://www.chicagobusiness.com/commercial-real-estate/apple-inc-closing-northbrook-court-store because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.chicagobusiness.com/commercial-real-estate/apple-inc-closing-northbrook-court-store on URL https://www.chicagobusiness.com/commercial-real-estate/apple-inc-closing-northbrook-court-store
# ⚠️ Failed to extract summary from https://www.patentlyapple.com/2025/02/a-federal-judge-has-invalidated-an-omni-medsci-patent-which-could-open-the-door-for-a-blood-glucose-solution-for-apple-watch.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.patentlyapple.com/2025/02/a-federal-judge-has-invalidated-an-omni-medsci-patent-which-could-open-the-door-for-a-blood-glucose-solution-for-apple-watch.html on URL https://www.patentlyapple.com/2025/02/a-federal-judge-has-invalidated-an-omni-medsci-patent-which-could-open-the-door-for-a-blood-glucose-solution-for-apple-watch.html
# ⚠️ Failed to extract summary from https://www.marketwatch.com/story/apple-may-have-to-raise-prices-of-the-iphone-to-offset-tariffs-says-bofa-4982fb4e because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/story/apple-may-have-to-raise-prices-of-the-iphone-to-offset-tariffs-says-bofa-4982fb4e on URL https://www.marketwatch.com/story/apple-may-have-to-raise-prices-of-the-iphone-to-offset-tariffs-says-bofa-4982fb4e
# ⚠️ Failed to extract summary from https://www.reuters.com/legal/litigation/apple-epic-games-head-back-court-over-app-store-order-2025-02-19/ because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/legal/litigation/apple-epic-games-head-back-court-over-app-store-order-2025-02-19/ on URL https://www.reuters.com/legal/litigation/apple-epic-games-head-back-court-over-app-store-order-2025-02-19/
# ⚠️ Failed to extract summary from https://seekingalpha.com/article/4759128-apple-ive-learned-not-to-bet-against-it-upgrade because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/article/4759128-apple-ive-learned-not-to-bet-against-it-upgrade on URL https://seekingalpha.com/article/4759128-apple-ive-learned-not-to-bet-against-it-upgrade
# ⚠️ Failed to extract summary from https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-reveals-first-custom-modem-chip-shifting-away-from-Qualcomm-49102487/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-reveals-first-custom-modem-chip-shifting-away-from-Qualcomm-49102487/ on URL https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-reveals-first-custom-modem-chip-shifting-away-from-Qualcomm-49102487/
# ⚠️ Failed to extract summary from https://www.proactiveinvestors.co.uk/companies/news/1066557/apple-launches-more-affordable-ai-powered-iphone-16e-1066557.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.proactiveinvestors.co.uk/companies/news/1066557/apple-launches-more-affordable-ai-powered-iphone-16e-1066557.html on URL https://www.proactiveinvestors.co.uk/companies/news/1066557/apple-launches-more-affordable-ai-powered-iphone-16e-1066557.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/02/18/fortem-financial-group-llc-has-6-97-million-stock-position-in-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/02/18/fortem-financial-group-llc-has-6-97-million-stock-position-in-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/02/18/fortem-financial-group-llc-has-6-97-million-stock-position-in-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.reuters.com/technology/french-antitrust-regulator-fines-apple-150-million-euros-over-privacy-tool-2025-03-31/ because Article `download()` failed with 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/technology/french-antitrust-regulator-fines-apple-150-million-euros-over-privacy-tool-2025-03-31/ on URL https://www.reuters.com/technology/french-antitrust-regulator-fines-apple-150-million-euros-over-privacy-tool-2025-03-31/
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4426970-rumored-apple-buy-of-nvidia-gpus-wouldnt-give-iphone-maker-ai-edge-anytime-soon-analyst because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4426970-rumored-apple-buy-of-nvidia-gpus-wouldnt-give-iphone-maker-ai-edge-anytime-soon-analyst on URL https://seekingalpha.com/news/4426970-rumored-apple-buy-of-nvidia-gpus-wouldnt-give-iphone-maker-ai-edge-anytime-soon-analyst
# ⚠️ Failed to extract summary from https://www.bloomberg.com/news/articles/2025-03-31/france-fines-apple-150-million-over-ios-data-tracking-consent because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.bloomberg.com/news/articles/2025-03-31/france-fines-apple-150-million-over-ios-data-tracking-consent on URL https://www.bloomberg.com/news/articles/2025-03-31/france-fines-apple-150-million-over-ios-data-tracking-consent
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4427052-apple-inches-up-as-foreign-branded-smartphone-shipments-climb-in-china-goldman-sachs because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4427052-apple-inches-up-as-foreign-branded-smartphone-shipments-climb-in-china-goldman-sachs on URL https://seekingalpha.com/news/4427052-apple-inches-up-as-foreign-branded-smartphone-shipments-climb-in-china-goldman-sachs
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4426945-foxconn-plans-to-make-up-to-30m-apple-iphones-in-india-in-2025---report because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4426945-foxconn-plans-to-make-up-to-30m-apple-iphones-in-india-in-2025---report on URL https://seekingalpha.com/news/4426945-foxconn-plans-to-make-up-to-30m-apple-iphones-in-india-in-2025---report
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4426781-france-antitrust-watchdog-fines-apple-162m-for-abusing-dominant-position because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4426781-france-antitrust-watchdog-fines-apple-162m-for-abusing-dominant-position on URL https://seekingalpha.com/news/4426781-france-antitrust-watchdog-fines-apple-162m-for-abusing-dominant-position
# ⚠️ Failed to extract summary from https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-Expands-Apple-Intelligence-Features-in-New-Regions-Languages-49487474/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-Expands-Apple-Intelligence-Features-in-New-Regions-Languages-49487474/ on URL https://www.marketscreener.com/quote/stock/APPLE-INC-4849/news/Apple-Expands-Apple-Intelligence-Features-in-New-Regions-Languages-49487474/
# ⚠️ Failed to extract summary from https://macdailynews.com/2025/03/31/shipments-of-foreign-branded-phones-including-apples-iphone-in-china-up-9-2-in-february/ because Article `download()` failed with 429 Client Error: Too Many Requests for url: https://macdailynews.com/2025/03/31/shipments-of-foreign-branded-phones-including-apples-iphone-in-china-up-9-2-in-february/ on URL https://macdailynews.com/2025/03/31/shipments-of-foreign-branded-phones-including-apples-iphone-in-china-up-9-2-in-february/
# ⚠️ Failed to extract summary from https://seekingalpha.com/news/4426753-musks-spacex-apple-at-loggerheads-over-satellite-internet because Article `download()` failed with 403 Client Error: Forbidden for url: https://seekingalpha.com/news/4426753-musks-spacex-apple-at-loggerheads-over-satellite-internet on URL https://seekingalpha.com/news/4426753-musks-spacex-apple-at-loggerheads-over-satellite-internet
# ⚠️ Failed to extract summary from https://www.benzinga.com/25/03/44555488/steve-jobs-didnt-fear-decision-fatigue-because-of-this-routine-now-gen-z-is-copying-his-outfit-playbook-to-stay-sane-stay-employed-and-stay-out-of-trouble-but-apple-co-founder-wasnt-the-only-one-with-this-peculiar-lifestyle-choice because Article `download()` failed with 429 Client Error: Too Many Requests for url: https://www.benzinga.com/25/03/44555488/steve-jobs-didnt-fear-decision-fatigue-because-of-this-routine-now-gen-z-is-copying-his-outfit-playbook-to-stay-sane-stay-employed-and-stay-out-of-trouble-but-apple-co-founder-wasnt-the-only-one-with-this-peculiar-lifestyle-choice on URL https://www.benzinga.com/25/03/44555488/steve-jobs-didnt-fear-decision-fatigue-because-of-this-routine-now-gen-z-is-copying-his-outfit-playbook-to-stay-sane-stay-employed-and-stay-out-of-trouble-but-apple-co-founder-wasnt-the-only-one-with-this-peculiar-lifestyle-choice
# ⚠️ Failed to extract summary from https://www.proactiveinvestors.com/companies/news/1068845/apple-and-spacex-clash-over-satellite-spectrum-rights-report-1068845.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.proactiveinvestors.com/companies/news/1068845/apple-and-spacex-clash-over-satellite-spectrum-rights-report-1068845.html on URL https://www.proactiveinvestors.com/companies/news/1068845/apple-and-spacex-clash-over-satellite-spectrum-rights-report-1068845.html
# ⚠️ Failed to extract summary from https://www.hindustantimes.com/business/apple-gets-fined-150-million-in-france-over-ios-data-tracking-consent-101743411678922.html because Article `download()` failed with 403 Client Error: Forbidden for url: https://www.hindustantimes.com/business/apple-gets-fined-150-million-in-france-over-ios-data-tracking-consent-101743411678922.html on URL https://www.hindustantimes.com/business/apple-gets-fined-150-million-in-france-over-ios-data-tracking-consent-101743411678922.html
# ⚠️ Failed to extract summary from https://guardian.ng/news/world/europe/france-fines-apple-150-million-euros-over-privacy-feature/ because Article `download()` failed with 403 Client Error: Forbidden for url: https://guardian.ng/news/world/europe/france-fines-apple-150-million-euros-over-privacy-feature/ on URL https://guardian.ng/news/world/europe/france-fines-apple-150-million-euros-over-privacy-feature/
# ⚠️ Failed to extract summary from https://www.annistonstar.com/news/nation_world/something-is-rotten-apples-ai-strategy-faces-doubts/article_6c66602d-7599-5880-a0e6-e468b18c287b.html because Article `download()` failed with 429 Client Error: Too Many Requests for url: https://www.annistonstar.com/news/nation_world/something-is-rotten-apples-ai-strategy-faces-doubts/article_6c66602d-7599-5880-a0e6-e468b18c287b.html on URL https://www.annistonstar.com/news/nation_world/something-is-rotten-apples-ai-strategy-faces-doubts/article_6c66602d-7599-5880-a0e6-e468b18c287b.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/31/spire-wealth-management-acquires-28404-shares-of-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/31/spire-wealth-management-acquires-28404-shares-of-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/31/spire-wealth-management-acquires-28404-shares-of-apple-inc-nasdaqaapl.html
# ⚠️ Failed to extract summary from https://www.defenseworld.net/2025/03/31/greenleaf-trust-acquires-7293-shares-of-apple-inc-nasdaqaapl.html because Article `download()` failed with 404 Client Error: Not Found for url: https://www.defenseworld.net/2025/03/31/greenleaf-trust-acquires-7293-shares-of-apple-inc-nasdaqaapl.html on URL https://www.defenseworld.net/2025/03/31/greenleaf-trust-acquires-7293-shares-of-apple-inc-nasdaqaapl.html

# %% [markdown]
# ### Análisis de sentimientos

# %% [markdown]
# Con los resumenes de los textos y con los títulos de las noticias, se procede a realizar la obtención del sentimiento de los mismos. Para ello, se optaron 3 librerías para poder entender cuál era aquella que nos sería más util: Textblob, Vader y FinBert. De acuerdo con los resultados y por su mejor similitud entre Vader y FinBert, nos quedamos con el último, ya que esta librería está enfocada en textos financieros.

# %% [markdown]
# #### Textblob y Vader

# %% [markdown]
# TextBlob: Librería basada en diccionarios y reglas gramaticales, adecuada para textos generales. Retorna un valor de polaridad entre -1 y +1. Se empleó como punto de referencia o línea base.
#
# VADER: Diseñado específicamente para textos cortos e informales, como titulares de noticias. Utiliza un enfoque basado en reglas lingüísticas para captar matices afectivos. También produce una puntuación entre -1 y +1.

# %%
# Cargar base de datos
df = pd.read_csv("combined_batches_summary.csv")

# Crear carpeta de salida para la etapa 1
os.makedirs("sentiment_batches_text", exist_ok=True)

# Inicializar VADER
vader = SentimentIntensityAnalyzer()

# Definir funciones de sentimiento
def get_textblob_sentiment(text):
    if isinstance(text, str) and text.strip():
        return TextBlob(text).sentiment.polarity
    return None

def get_vader_sentiment(text):
    if isinstance(text, str) and text.strip():
        return vader.polarity_scores(text)['compound']
    return None

# Procesamiento en batches
batch_size = 1000
total_rows = len(df)

for i in range(0, total_rows, batch_size):
    end = min(i + batch_size, total_rows)
    print(f"\n📝 Processing TextBlob & VADER: Rows {i} to {end}")

    batch = df.iloc[i:end].copy()

    tqdm.pandas(desc="TextBlob title")
    batch['textblob_title_score'] = batch['title'].progress_apply(get_textblob_sentiment)

    tqdm.pandas(desc="TextBlob summary")
    batch['textblob_summary_score'] = batch['summary'].progress_apply(get_textblob_sentiment)

    tqdm.pandas(desc="VADER title")
    batch['vader_title_score'] = batch['title'].progress_apply(get_vader_sentiment)

    tqdm.pandas(desc="VADER summary")
    batch['vader_summary_score'] = batch['summary'].progress_apply(get_vader_sentiment)

    # Guardar el batch con solo TextBlob/VADER
    output_file = f"sentiment_batches_text/sentiment_batch_text_{i}_{end}.csv"
    batch.to_csv(output_file, index=False)
    print(f"✅ Saved batch to {output_file}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 nltk.download('punkt')
#       3 # Load base data
#       4 df = pd.read_csv("tesla_press_data.csv")
#
# NameError: name 'nltk' is not defined

# %% [markdown]
# #### FinBert

# %% [markdown]
# Modelo basado en la arquitectura BERT, entrenado específicamente con textos del ámbito financiero. Clasifica cada entrada como positiva, neutral o negativa, y permite calcular un puntaje ponderado en función de la distribución de dichas categorías. Su diseño especializado lo hace especialmente adecuado para contextos bursátiles y económicos.

# %%
# Organizar carpetas
input_folder = "sentiment_batches_text"
output_folder = "sentiment_batches_full"
os.makedirs(output_folder, exist_ok=True)

# FinBERT
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")
labels = ['negative', 'neutral', 'positive']

# Función para Finbert
def get_finbert_label_and_score(text):
    if not isinstance(text, str) or len(text.strip()) < 5:
        return (None, None)
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        outputs = model(**inputs)
    probs = softmax(outputs.logits.numpy()[0])
    best_idx = probs.argmax()
    return (labels[best_idx], float(probs[best_idx]))
# Out:
# /opt/tljh/user/lib/python3.9/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %%
# Detectar el último batch realizado
existing_outputs = [
    f for f in os.listdir(output_folder)
    if f.startswith("sentiment_batch_full_") and f.endswith(".csv")
]

if existing_outputs:
    # Extraer el mayor número del nombre
    last_index = max([
        int(f.split("_")[-1].replace(".csv", ""))
        for f in existing_outputs
    ])
else:
    last_index = -1  # aún no hay nada procesado

# Procesar el siguiente batch
input_files = sorted([
    f for f in os.listdir(input_folder)
    if f.startswith("sentiment_batch_text_") and f.endswith(".csv")
])

for file in input_files:
    file_index = int(file.split("_")[-1].replace(".csv", ""))
    if file_index <= last_index:
        continue  # ya fue procesado

    input_path = os.path.join(input_folder, file)
    output_path = os.path.join(output_folder, file.replace("text", "full"))

    print(f"\n🔄 Procesando {file}")
    df = pd.read_csv(input_path)

    # FinBERT para título
    tqdm.pandas(desc="FinBERT title sentiment")
    title_result = df['title'].progress_apply(get_finbert_label_and_score)
    df['finbert_title_label'] = title_result.apply(lambda x: x[0])
    df['finbert_title_score'] = title_result.apply(lambda x: x[1])

    # FinBERT para resumen
    tqdm.pandas(desc="FinBERT summary sentiment")
    summary_result = df['summary'].progress_apply(get_finbert_label_and_score)
    df['finbert_summary_label'] = summary_result.apply(lambda x: x[0])
    df['finbert_summary_score'] = summary_result.apply(lambda x: x[1])

    # Guardar
    df.to_csv(output_path, index=False)
    print(f"✅ Guardado: {output_path}")
# Out:
# 🔄 Processing sentiment_batch_text_22000_22753.csv
# FinBERT title sentiment:   0%|          | 0/753 [00:00<?, ?it/s]
# FinBERT summary sentiment:   0%|          | 0/753 [00:00<?, ?it/s]
# ✅ Saved to sentiment_batches_full/sentiment_batch_full_22000_22753.csv

# %%
# Batches de FinBERT
folder_path = "/home/jupyter-sebas/sentiment_batches_full" # ajustar esta ruta según el entorno desde donde se ejecute el código

# Listar todos los csvs en el folder
csv_files = sorted([f for f in os.listdir(folder_path) if f.endswith(".csv")])

# Cargarlos y coleccionarlos en un Dataframe
df_list = []

for file in csv_files:
    path = os.path.join(folder_path, file)
    df = pd.read_csv(path)
    df_list.append(df)

# Combinarlos
df_full = pd.concat(df_list, ignore_index=True)

# Guardarlo en un csv
df_full.to_csv("tesla_sentiment_full.csv", index=False)
print(f"Se combinaron {len(csv_files)} archivos con éxito ")
# Out:
# ✅ Done! Combined 22 files into 'tesla_sentiment_full.csv'

# %%
# Cargar el DF
df = pd.read_csv("tesla_sentiment_full.csv")

# FinBERT devuelve una probabilidad y un label si es que es positivo, neutro o negativo. Por lo tanto, creamos nuestro puntaje propio (label * score)
def scale_label_with_confidence(label, score):
    label_to_weight = {
        "positive": 1,
        "neutral": 0,
        "negative": -1
    }
    if pd.isna(label) or pd.isna(score):
        return None
    return label_to_weight.get(label.lower(), 0) * score

# %%
# Se obtiene el puntaje asociado al título
df['finbert_title_sentiment_score'] = df.apply(
    lambda row: scale_label_with_confidence(row['finbert_title_label'], row['finbert_title_score']),
    axis=1
)

# Se obtiene el puntaje asociado al resumen
df['finbert_summary_sentiment_score'] = df.apply(
    lambda row: scale_label_with_confidence(row['finbert_summary_label'], row['finbert_summary_score']),
    axis=1
)

# %%
df.to_csv("tesla_sentiment_full_weighted.csv", index=False)
print("Se guardó con éxito el archivo csv")
# Out:
# ✅ Saved final file with FinBERT sentiment scores to 'tesla_sentiment_full_weighted.csv'

# %%
df = pd.read_csv("tesla_sentiment_full_weighted.csv")

# %%
# Como se mencionó previamente, existen algunas noticias que no se pudieron procesar correctamente, debido a restricciones o a mecanismos de detección
# que identificaban la solicitud como proveniente de un bot. Por lo tanto, en los casos en que no se logró extraer el resumen, se optó por utilizar como alternativa
# el título de la noticia junto con su respectiva puntuación de sentimiento.

df['finbert_final_sentiment'] = df['finbert_summary_sentiment_score'].combine_first(
    df['finbert_title_sentiment_score']
)

# %%
df.to_csv("tesla_sentiment_final.csv")

# %% [markdown]
# #### FinBERT embeddings

# %% [markdown]
# En esta sección se genera una representación numérica (embedding) del contenido textual de cada noticia utilizando el modelo preentrenado **FinBERT**, una versión de BERT adaptada específicamente al lenguaje financiero.
#
# Cada embedding es un vector de 768 dimensiones que captura el significado semántico del texto, incluyendo tono, contexto financiero y entidades mencionadas. Estos vectores permiten representar el contenido de la noticia de forma que pueda ser utilizada como input en modelos de predicción, como LSTM.
#
# Para cada artículo, se utiliza el **summary** si está disponible, o el **title** en su defecto, asegurando así una cobertura completa del dataset.

# %%
# Cargar el archivo CSV con los datos finales de Tesla
df = pd.read_csv("tesla_final_data.csv")

# %%
# Seleccionar solo las columnas relevantes para el análisis
df = df[['title', 'publish_date', 'expanded_url', 'source', 'summary', 'finbert_final_sentiment']]

# %%
# Mostrar la primera fila del DataFrame como muestra
df.head(1)
# Out:
#                                                title publish_date  \
# 0  Product of the Week: Advantech’s NVIDIA Jetson...   2022-03-15
#
#                                         expanded_url  \
# 0  https://embeddedcomputing.com/technology/ai-ma...
#
#                       source  \
# 0  Embedded Computing Design
#
#                                              summary  finbert_final_sentiment
# 0  Product of the Week: Advantech’s NVIDIA Jetson...                 0.861443

# %%
# Configuración
company_name = "tesla"
output_folder = f"embedding_batches_{company_name}"
batch_size = 1000
os.makedirs(output_folder, exist_ok=True)

# Cargar modelo FinBERT
tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
model = AutoModel.from_pretrained("ProsusAI/finbert")

# Determinar texto a usar
df['text_input'] = df['summary'].fillna(df['title'])

# Encontrar último batch completado
existing_batches = [f for f in os.listdir(output_folder) if f.startswith("embedding_batch_")]
if existing_batches:
    last_batch = max(int(f.split("_")[-1].split(".")[0]) for f in existing_batches)
    start_row = last_batch * batch_size
    print(f"📦 Retomando desde batch {last_batch + 1}, fila {start_row}")
else:
    last_batch = 0
    start_row = 0
    print("Iniciando desde el principio")

# Función de embeddings
def get_embedding(text):
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=128)
    with torch.no_grad():
        outputs = model(**inputs)
        return outputs.last_hidden_state.mean(dim=1).squeeze().numpy()

# Procesar en batches
num_batches = (len(df) // batch_size) + 1
for batch_num in range(last_batch, num_batches):
    start = batch_num * batch_size
    end = min((batch_num + 1) * batch_size, len(df))
    chunk = df.iloc[start:end].copy()

    print(f"Batch {batch_num + 1}/{num_batches}: Filas {start} a {end}")

    embeddings = []
    for text in tqdm(chunk['text_input'], desc=f"Embedding batch {batch_num + 1}", leave=False):
        try:
            emb = get_embedding(text)
        except Exception as e:
            print(f"Error en texto: {e}")
            emb = [None] * model.config.hidden_size
        embeddings.append(emb)

    emb_df = pd.DataFrame(embeddings)
    result = pd.concat([chunk.reset_index(drop=True), emb_df], axis=1)

    result.to_csv(f"{output_folder}/embedding_batch_{batch_num + 1}.csv", index=False)
    print(f"Guardado: embedding_batch_{batch_num + 1}.csv")
# Out:
# 🆕 Iniciando desde el principio
# 🔄 Batch 1/39: Filas 0 a 1000
# ✅ Guardado: embedding_batch_1.csv
# 🔄 Batch 2/39: Filas 1000 a 2000
# ✅ Guardado: embedding_batch_2.csv
# 🔄 Batch 3/39: Filas 2000 a 3000
# ✅ Guardado: embedding_batch_3.csv
# 🔄 Batch 4/39: Filas 3000 a 4000
# ✅ Guardado: embedding_batch_4.csv
# 🔄 Batch 5/39: Filas 4000 a 5000
# 🧠 Embedding batch 5:  42%|███████▌          | 418/1000 [00:15<00:22, 25.81it/s]

# %%
# Ruta del folder donde están los batches de embeddings

embedding_folder = f"embedding_batches_{company_name}"
output_file = f"{company_name}_final_news.csv"

# Listar todos los CSVs que empiecen con "embedding_batch_"
embedding_files = sorted([
    f for f in os.listdir(embedding_folder)
    if f.endswith(".csv") and f.startswith("embedding_batch_")
])

# Leer y acumular los archivos
dfs = []
for file in embedding_files:
    path = os.path.join(embedding_folder, file)
    df = pd.read_csv(path)
    dfs.append(df)

# Concatenar todo
final_df = pd.concat(dfs, ignore_index=True)

# Guardar como archivo final
final_df.to_csv(output_file, index=False)
print(f"Archivo final guardado como: {output_file}")
print(f"Total de filas: {len(final_df)}")
# Out:
# ✅ Archivo final guardado como: tesla_final_news.csv
# 🧾 Total de filas: 21753

# %% [markdown]
# #### Dataframe final

# %%
# Cargar el archivo CSV con las noticias finales de Tesla y mostrar la primera fila
df = pd.read_csv("tesla_final_news_1.csv")
df.head(1)
# Out:
#                                                title publish_date  \
# 0  Product of the Week: Advantech’s NVIDIA Jetson...   2022-03-15
#
#                                         expanded_url  \
# 0  https://embeddedcomputing.com/technology/ai-ma...
#
#                       source  \
# 0  Embedded Computing Design
#
#                                              summary  finbert_final_sentiment  \
# 0  Product of the Week: Advantech’s NVIDIA Jetson...                 0.861443
#
#                                           text_input         0         1  \
# 0  Product of the Week: Advantech’s NVIDIA Jetson... -0.076522  0.367546
#
#           2  ...       758       759       760       761       762       763  \
# 0  0.218021  ... -0.407227  0.070884  0.000212 -0.348598 -0.482147  0.260011
#
#         764       765       766       767
# 0  0.212645 -0.593635 -0.369286  0.021706
#
# [1 rows x 775 columns]

# %%
# Convertir la columna 'publish_date' a formato datetime
df['publish_date'] = pd.to_datetime(df['publish_date'], errors='coerce')

# Crear una lista con los nombres de las columnas que representan los embeddings (768 dimensiones)
embedding_cols = [str(i) for i in range(768)]

# Agrupar por fecha y calcular promedios
daily_aggregated_df = df.groupby('publish_date')[
    ['finbert_final_sentiment'] + embedding_cols
].mean().reset_index()

print(daily_aggregated_df.head())
# Out:
#   publish_date  finbert_final_sentiment         0         1         2  \
# 0   2019-01-02                 0.879671 -0.160438  0.193722  0.493397
# 1   2019-01-03                 0.788898  0.059528  0.282742  0.287097
# 2   2019-01-04                 0.804486 -0.156126  0.315028  0.020149
# 3   2019-01-05                -0.611471 -0.195891  0.151220  0.236809
# 4   2019-01-06                 0.578500 -0.082699  0.193885  0.432415
#
#           3         4         5         6         7  ...       758       759  \
# 0 -0.052131  0.442112 -0.464578 -0.171742  0.526781  ... -0.065640  0.428596
# 1  0.139335  0.282810 -0.360812 -0.109893  0.553889  ... -0.324254  0.238413
# 2  0.245867  0.231768 -0.288947 -0.028763  0.415299  ... -0.233439  0.249639
# 3  0.021907  0.064496 -0.296357 -0.419981 -0.108710  ... -0.189058  0.247177
# 4  0.034823  0.388871 -0.509751 -0.200984  0.452561  ... -0.349684  0.240410
#
#         760       761       762       763       764       765       766  \
# 0 -0.129482 -0.573310 -0.391112  0.142601  0.137166 -0.571954 -0.336185
# 1  0.049422 -0.495550 -0.360229  0.209155  0.152206 -0.419530 -0.129677
# 2  0.226610 -0.397211 -0.445424  0.270341  0.324112 -0.533003 -0.257079
# 3  0.239496 -0.568276 -0.282004  0.328723  0.030842 -0.428282 -0.131717
# 4  0.062072 -0.416689 -0.366047  0.281648  0.046215 -0.350625 -0.253961
#
#         767
# 0  0.124521
# 1  0.127384
# 2 -0.013377
# 3  0.054793
# 4 -0.006404
#
# [5 rows x 770 columns]

# %%
# Guardar el DataFrame con los datos agregados diarios en un archivo CSV
daily_aggregated_df.to_csv("tesla_sentiment.csv")
